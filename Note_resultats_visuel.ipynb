# %% [markdown]
# ### Query sqlite

# %% [markdown]
# ### 1- Importation des packages

# %%
# Base de données 
import pandas as pd # pour lire et analyser des tableaux de données(fichiers Excel, CSV…)
import numpy as np # pour faire des calculs numériques rapides et manipuler des tableaux de nombres.
import sqlite3  ### permet de lire et ecrire des query 

# Dataviz
import matplotlib.pyplot as plt # pour créer des graphiques simples
import seaborn as sns # pour faire des visualisations de données plus jolies et détaillées
import plotly.express as px # Pour des visuel intéractif 
# Statistiques
import scipy.stats as stat # pour réaliser des analyses statistiques (moyenne, test de corrélation...)

# lecture des urls et api 
import requests   ### pas utiliser car c'est pour lire les données issue des urls ou api

# %% [markdown]
# 2- Importation des fichiers csv via le google drive

# %%
# 1- Définir les variables 
chemin_fichier_magasin = r"G:\Mon Drive\Brief projet simplon\BDD\magasins.csv"
chemin_fichier_produit  = r"G:\Mon Drive\Brief projet simplon\BDD\produits.csv"
chemin_fichier_vente  = r"G:\Mon Drive\Brief projet simplon\BDD\ventes.csv"

# %%
# 2. Stockage des données dans un df 
df_magasin = pd.read_csv(chemin_fichier_magasin)
df_produit = pd.read_csv(chemin_fichier_produit)
df_vente = pd.read_csv(chemin_fichier_vente)

# %%
# 3- Lecture des df pour vérification
df_magasin
# Out:
#    id_magasin       ville  nombre_de_salaries
# 0           1       Paris                  10
# 1           2   Marseille                   5
# 2           3        Lyon                   8
# 3           4    Bordeaux                  12
# 4           5       Lille                   6
# 5           6      Nantes                   7
# 6           7  Strasbourg                   9

# %%
# 3- Lecture des df pour vérification
df_produit
# Out:
#          nom id_reference_produits   prix  stock
# 0  Produit A                REF001  49.99    100
# 1  Produit B                REF002  19.99     50
# 2  Produit C                REF003  29.99     75
# 3  Produit D                REF004  79.99    120
# 4  Produit E                REF005  39.99     80

# %%
# 3- Lecture des df pour vérification
df_vente
# Out:
#           date id_reference_produits  quantite  id_magasin
# 0   2023-05-27                REF001         5           1
# 1   2023-05-28                REF002         3           2
# 2   2023-05-29                REF003         2           1
# 3   2023-05-30                REF004         4           3
# 4   2023-05-31                REF005         7           2
# 5   2023-06-01                REF001         3           4
# 6   2023-06-02                REF002         6           1
# 7   2023-06-03                REF003         1           5
# 8   2023-06-04                REF004         2           3
# 9   2023-06-05                REF005         5           6
# 10  2023-06-06                REF001         4           7
# 11  2023-06-07                REF002         3           2
# 12  2023-06-08                REF003         6           4
# 13  2023-06-09                REF004         2           1
# 14  2023-06-10                REF005         8           3
# ...
